// %% [markdown]
// <div style="
//     font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, 'Helvetica Neue', Arial, sans-serif;
//     background: linear-gradient(135deg, #1e1e2f, #13111c);
//     padding: 20px 28px;
//     border-radius: 20px;
//     margin: 20px 0;
//     border: 1px solid rgba(156, 110, 255, 0.2);
//     box-shadow: 0 10px 25px rgba(0,0,0,0.5), inset 0 1px 0 rgba(255,255,255,0.05);
//     backdrop-filter: blur(2px);
// ">
//     <div style="
//         display: flex;
//         align-items: center;
//         gap: 14px;
//     ">
//         <div style="
//             background: linear-gradient(145deg, #7F52FF, #5a3fb5);
//             width: 44px;
//             height: 44px;
//             border-radius: 14px;
//             display: inline-flex;
//             align-items: center;
//             justify-content: center;
//             font-size: 24px;
//             box-shadow: 0 6px 14px rgba(127,82,255,0.4);
//         ">
//             🧠
//         </div>
//         <h3 style="
//             margin: 0;
//             font-size: 1.65rem;
//             font-weight: 600;
//             color: #E0D4FF;
//             letter-spacing: -0.3px;
//             text-shadow: 0 1px 2px rgba(0,0,0,0.3);
//         ">
//             Condiciones en Kotlin
//         </h3>
//     </div>
//     <div style="
//         height: 3px;
//         width: 80px;
//         background: linear-gradient(90deg, #9C6EFF, #7F52FF, #B39DDB);
//         border-radius: 3px;
//         margin-top: 15px;
//         box-shadow: 0 0 8px #7F52FF;
//     "></div>
// </div>

// %% [markdown]
// <div style="font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, 'Helvetica Neue', Arial, sans-serif; background: linear-gradient(135deg, #1e1e2f, #13111c); padding: 20px 28px; border-radius: 20px; margin: 20px 0; border: 1px solid rgba(156, 110, 255, 0.2); box-shadow: 0 10px 25px rgba(0,0,0,0.5), inset 0 1px 0 rgba(255,255,255,0.05); backdrop-filter: blur(2px);"><!-- Encabezado principal -->
// <div style="display: flex; align-items: center; gap: 12px; margin-bottom: 16px;">
// <div style="background: linear-gradient(145deg, #7F52FF, #5a3fb5); width: 36px; height: 36px; border-radius: 12px; display: inline-flex; align-items: center; justify-content: center; font-size: 18px; font-weight: bold; color: white; box-shadow: 0 4px 10px rgba(127,82,255,0.3);">1</div>
// <h3 style="margin: 0; font-size: 1.5rem; font-weight: 600; color: #e0d4ff; letter-spacing: -0.3px;"><code style="background: rgba(127, 82, 255, 0.2); padding: 4px 8px; border-radius: 8px; font-family: 'SF Mono', 'Fira Code', monospace; font-size: 1.3rem; color: #b39ddb; border: 1px solid rgba(127,82,255,0.3);">if</code> / <code style="background: rgba(127, 82, 255, 0.2); padding: 4px 8px; border-radius: 8px; font-family: 'SF Mono', 'Fira Code', monospace; font-size: 1.3rem; color: #b39ddb; border: 1px solid rgba(127,82,255,0.3);">else if</code> / <code style="background: rgba(127, 82, 255, 0.2); padding: 4px 8px; border-radius: 8px; font-family: 'SF Mono', 'Fira Code', monospace; font-size: 1.3rem; color: #b39ddb; border: 1px solid rgba(127,82,255,0.3);">else</code></h3>
// </div>
// <details>
// <summary>Ver más</summary>
// <!-- Bloque de definición de condición -->
// <div style="background: rgba(255, 255, 255, 0.03); border-left: 3px solid #7F52FF; padding: 12px 16px; border-radius: 12px; margin: 16px 0;">
// <h3 style="margin: 0; font-size: 1.1rem; font-weight: 500; color: #ccc5f0; line-height: 1.5;">Una <strong style="color: #e0d4ff;">condici&oacute;n</strong> es una pregunta que solo puede tener dos respuestas: <strong style="color: #a5d6ff;">verdadero (<code style="background: rgba(127, 82, 255, 0.25); padding: 2px 6px; border-radius: 6px; font-family: monospace; color: #a5d6ff;">true</code>)</strong> o <strong style="color: #ffb4a2;">falso (<code style="background: rgba(127, 82, 255, 0.25); padding: 2px 6px; border-radius: 6px; font-family: monospace; color: #ffb4a2;">false</code>)</strong>.</h3>
// </div>
// <!-- Descripción básica -->
// <p style="margin: 12px 0 8px 0; color: #b8b0e0; font-size: 0.95rem; line-height: 1.5;"> Eval&uacute;a condiciones booleanas de forma secuencial.</p>
// <!-- Lista de características (nuevo contenido con estilo uniforme) -->
// <ul style="margin: 16px 0; padding-left: 24px; color: #b8b0e0; font-size: 0.9rem; line-height: 1.6;">
// <li style="margin: 10px 0; list-style-type: '✨ ';">Eval&uacute;a &uacute;nicamente <strong style="color: #e0d4ff;">expresiones booleanas</strong> (<code style="background: rgba(127, 82, 255, 0.2); padding: 2px 6px; border-radius: 6px; font-family: monospace; color: #b39ddb;">true</code> / <code style="background: rgba(127, 82, 255, 0.2); padding: 2px 6px; border-radius: 6px; font-family: monospace; color: #b39ddb;">false</code>), no acepta enteros u otros tipos como condici&oacute;n.</li>
// <li style="margin: 10px 0; list-style-type: '📌 ';">El bloque <code style="background: rgba(127, 82, 255, 0.2); padding: 2px 6px; border-radius: 6px; font-family: monospace; color: #b39ddb;">else</code> es <strong style="color: #ffb4a2;">opcional</strong> cuando se usa como sentencia, pero <strong style="color: #a5d6ff;">obligatorio</strong> cuando se usa como expresi&oacute;n.</li>
// <li style="margin: 10px 0; list-style-type: '🎯 ';">Cuando se usa como expresi&oacute;n, retorna el <strong style="color: #e0d4ff;">valor de la &uacute;ltima l&iacute;nea</strong> del bloque ejecutado.</li>
// <li style="margin: 10px 0; list-style-type: '🔗 ';">Puede encadenarse con <code style="background: rgba(127, 82, 255, 0.2); padding: 2px 6px; border-radius: 6px; font-family: monospace; color: #b39ddb;">else if</code> para evaluar <strong style="color: #e0d4ff;">m&uacute;ltiples condiciones</strong> de forma secuencial.</li>
// <li style="margin: 10px 0; list-style-type: '⬇️ ';">Las condiciones se eval&uacute;an <strong style="color: #e0d4ff;">de arriba hacia abajo</strong> y se detiene en la primera que sea verdadera.</li>
// <li style="margin: 10px 0; list-style-type: '🔄 ';"><strong style="color: #ffd966;">Reemplaza al operador ternario</strong> <code style="background: rgba(127, 82, 255, 0.2); padding: 2px 6px; border-radius: 6px; font-family: monospace; color: #b39ddb;">? :</code> de Java/C, ya que cumple la misma funci&oacute;n como expresi&oacute;n.</li>
// </ul>
// <!-- Bloque destacado de característica única de Kotlin -->
// <div style="background: linear-gradient(135deg, rgba(127,82,255,0.08), rgba(92,60,180,0.05)); padding: 12px 16px; border-radius: 12px; margin-top: 16px; border: 1px solid rgba(127,82,255,0.15);">
// <p style="margin: 0; color: #ccc5f0; font-size: 0.9rem; font-weight: 500;">⚡ <strong style="color: #b39ddb;">Caracter&iacute;stica &uacute;nica en Kotlin:</strong> <span style="color: #c8e0ff;">puede usarse como <strong style="color: #ffd966;">expresi&oacute;n</strong> que retorna un valor</span></p>
// </div>
// <!-- Línea decorativa inferior -->
// <div style="height: 3px; width: 60px; background: linear-gradient(90deg, #9C6EFF, #7F52FF, #B39DDB); border-radius: 3px; margin-top: 20px; box-shadow: 0 0 8px #7F52FF;">&nbsp;</div>
// </details>
// </div>

// %% [markdown]
// <div style="font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, 'Helvetica Neue', Arial, sans-serif; background: linear-gradient(135deg, #1e1e2f, #13111c); padding: 20px 28px; border-radius: 20px; margin: 20px 0; border: 1px solid rgba(156, 110, 255, 0.2); box-shadow: 0 10px 25px rgba(0,0,0,0.5), inset 0 1px 0 rgba(255,255,255,0.05); backdrop-filter: blur(2px);"><!-- Encabezado principal -->
// <div style="display: flex; align-items: center; gap: 12px; margin-bottom: 16px;">
// <div style="background: linear-gradient(145deg, #7F52FF, #5a3fb5); width: 36px; height: 36px; border-radius: 12px; display: inline-flex; align-items: center; justify-content: center; font-size: 18px; font-weight: bold; color: white; box-shadow: 0 4px 10px rgba(127,82,255,0.3);">2</div>
// <h3 style="margin: 0; font-size: 1.5rem; font-weight: 600; color: #e0d4ff; letter-spacing: -0.3px;"><code style="background: rgba(127, 82, 255, 0.2); padding: 4px 8px; border-radius: 8px; font-family: 'SF Mono', 'Fira Code', monospace; font-size: 1.3rem; color: #b39ddb; border: 1px solid rgba(127,82,255,0.3);">when</code></h3>
// </div>
// <!-- Detalles desplegables (summary + contenido) -->
// <details style="margin: 16px 0; background: rgba(255, 255, 255, 0.02); border-radius: 14px; padding: 0;">
// <summary style="cursor: pointer; padding: 12px 16px; font-weight: 600; color: #b39ddb; font-size: 0.95rem; background: rgba(127, 82, 255, 0.1); border-radius: 14px; transition: all 0.2s ease; list-style: none; display: inline-block; width: auto; user-select: none;">📖 Ver m&aacute;s</summary>
// <div style="padding: 16px; margin-top: 8px;"><!-- Descripción principal -->
// <p style="margin: 0 0 16px 0; color: #b8b0e0; font-size: 0.95rem; line-height: 1.5; background: rgba(255, 255, 255, 0.03); padding: 12px 16px; border-radius: 12px; border-left: 3px solid #7F52FF;">Eval&uacute;a un valor contra m&uacute;ltiples casos aunque tambi&eacute;n puede usarse como <strong style="color: #ffd966;">expresi&oacute;n</strong></p>
// <!-- Lista de características -->
// <ul style="margin: 0; padding-left: 24px; color: #b8b0e0; font-size: 0.9rem; line-height: 1.6;">
// <li style="margin: 10px 0; list-style-type: '🚀 ';">Es el <strong style="color: #e0d4ff;">reemplazo mejorado</strong> del <code style="background: rgba(127, 82, 255, 0.2); padding: 2px 6px; border-radius: 6px; font-family: monospace; color: #b39ddb;">switch</code> de Java, con muchas m&aacute;s capacidades.</li>
// <li style="margin: 10px 0; list-style-type: '💡 ';">Tambi&eacute;n es una <strong style="color: #e0d4ff;">expresi&oacute;n</strong>, por lo que puede retornar un valor y asignarse a una variable.</li>
// <li style="margin: 10px 0; list-style-type: '🔓 ';"><strong style="color: #a5d6ff;">No requiere <code style="background: rgba(127, 82, 255, 0.2); padding: 2px 6px; border-radius: 6px; font-family: monospace; color: #b39ddb;">break</code></strong> al final de cada rama.</li>
// <li style="margin: 10px 0; list-style-type: '🎯 ';">Puede comparar el valor contra <strong style="color: #e0d4ff;">valores exactos, rangos (<code style="background: rgba(127, 82, 255, 0.2); padding: 2px 6px; border-radius: 6px; font-family: monospace; color: #b39ddb;">in</code>), tipos (<code style="background: rgba(127, 82, 255, 0.2); padding: 2px 6px; border-radius: 6px; font-family: monospace; color: #b39ddb;">is</code>) y condiciones arbitrarias</strong>.</li>
// <li style="margin: 10px 0; list-style-type: '🔗 ';">Permite agrupar <strong style="color: #e0d4ff;">m&uacute;ltiples valores en una sola rama</strong> separ&aacute;ndolos con coma.</li>
// <li style="margin: 10px 0; list-style-type: '⚙️ ';">Puede usarse <strong style="color: #e0d4ff;">con o sin argumento</strong>; sin argumento act&uacute;a como un <code style="background: rgba(127, 82, 255, 0.2); padding: 2px 6px; border-radius: 6px; font-family: monospace; color: #b39ddb;">if-else if</code> encadenado.</li>
// <li style="margin: 10px 0; list-style-type: '📌 ';">El bloque <code style="background: rgba(127, 82, 255, 0.2); padding: 2px 6px; border-radius: 6px; font-family: monospace; color: #b39ddb;">else</code> es <strong style="color: #ffb4a2;">obligatorio como expresi&oacute;n</strong> si no se cubren todos los casos posibles.</li>
// <li style="margin: 10px 0; list-style-type: '📦 ';">Cada rama puede contener <strong style="color: #e0d4ff;">un bloque de c&oacute;digo completo</strong> con m&uacute;ltiples instrucciones usando llaves <code style="background: rgba(127, 82, 255, 0.2); padding: 2px 6px; border-radius: 6px; font-family: monospace; color: #b39ddb;">{}</code>.</li>
// </ul>
// </div>
// </details>
// <!-- Línea decorativa inferior -->
// <div style="height: 3px; width: 60px; background: linear-gradient(90deg, #9C6EFF, #7F52FF, #B39DDB); border-radius: 3px; margin-top: 20px; box-shadow: 0 0 8px #7F52FF;">&nbsp;</div>
// </div>

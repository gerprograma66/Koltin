// %% [markdown]
// <div style="font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, 'Helvetica Neue', Arial, sans-serif; background: #1e1e2f; padding: 52px 60px; border-radius: 36px; margin: 36px 0; border: 2px solid #7F52FF; box-shadow: 0 8px 20px rgba(0,0,0,0.4);"><!-- Título principal -->
// <div style="display: flex; align-items: center; gap: 24px; margin-bottom: 36px;">
// <div style="background: #7F52FF; width: 72px; height: 72px; border-radius: 22px; display: inline-flex; align-items: center; justify-content: center; font-size: 40px;">🎓</div>
// <h3 style="margin: 0; font-size: 2.8rem; font-weight: bold; color: #e0d4ff;">Ejercicio: Sistema de Descuentos en Tienda</h3>
// </div>
// <!-- Enunciado -->
// <div style="background: #252540; border-left: 5px solid #7F52FF; padding: 24px 32px; border-radius: 20px; margin: 28px 0;">
// <p style="margin: 0; font-size: 1.8rem; font-weight: 600; color: #ccc5f0;">📋 Enunciado</p>
// <p style="margin: 14px 0 0 0; color: #b8b0e0; font-size: 1.6rem; line-height: 1.5;">Una tienda de ropa aplica descuentos a sus clientes seg&uacute;n su tipo de membres&iacute;a y el total de su compra. Tu tarea es crear un programa en Kotlin que calcule el precio final que debe pagar el cliente.</p>
// </div>
// <!-- Datos del problema -->
// <div style="background: #252540; border-left: 5px solid #7F52FF; padding: 24px 32px; border-radius: 20px; margin: 28px 0;">
// <p style="margin: 0; font-size: 1.8rem; font-weight: 600; color: #ccc5f0;">📌 Datos del problema</p>
// <p style="margin: 14px 0 0 0; color: #b8b0e0; font-size: 1.6rem; line-height: 1.5;"><strong style="color: #ffd966;">Descuentos a aplicar:</strong><br>&bull; Descuento membres&iacute;a REGULAR &rarr; 5%<br>&bull; Descuento membres&iacute;a PREMIUM &rarr; 15%<br>&bull; Descuento membres&iacute;a VIP &rarr; 25%<br>&bull; Compra m&iacute;nima para descuento &rarr; 200</p>
// <p style="margin: 20px 0 0 0; color: #b8b0e0; font-size: 1.6rem; line-height: 1.5;"><strong style="color: #a5d6ff;">Datos del cliente:</strong><br>&bull; Nombre del cliente<br>&bull; Tipo de membres&iacute;a ("REGULAR", "PREMIUM" o "VIP")<br>&bull; Total de la compra antes del descuento</p>
// </div>
// <!-- Condiciones -->
// <div style="background: #252540; border-left: 5px solid #7F52FF; padding: 24px 32px; border-radius: 20px; margin: 28px 0;">
// <p style="margin: 0; font-size: 1.8rem; font-weight: 600; color: #ccc5f0;">✅ Condiciones que debe cumplir tu programa</p>
// <ul style="margin: 14px 0 0 0; padding-left: 36px; color: #b8b0e0; font-size: 1.5rem; line-height: 1.65;">
// <li style="margin: 10px 0;">Si el total de compra no supera los $200, no se aplica ning&uacute;n descuento</li>
// <li style="margin: 10px 0;">Si supera los 200, aplicar el descuento seg&uacute;n el tipo de membres&iacute;a</li>
// <li style="margin: 10px 0;">Si el tipo de membres&iacute;a ingresado no es v&aacute;lido, mostrar un mensaje de error</li>
// <li style="margin: 10px 0;">Mostrar siempre: nombre del cliente, total original, descuento aplicado y total a pagar</li>
// </ul>
// </div>
// <!-- Ejemplos de salida -->
// <div style="background: #1a1a30; padding: 24px 32px; border-radius: 20px; margin: 28px 0; border: 2px solid #7F52FF;">
// <p style="margin: 0; font-size: 1.8rem; font-weight: 600; color: #ccc5f0;">💡 Ejemplo de salida esperada</p>
// <!-- Ejemplo 1 -->
// <div style="background: #0f0f1a; padding: 20px 24px; border-radius: 16px; margin: 20px 0; font-family: monospace; font-size: 1.4rem; color: #a5d6ff; line-height: 1.6;">Cliente: Ana Mart&iacute;nez<br>Membres&iacute;a: PREMIUM<br>Total original: 350.0<br>Descuento aplicado: 15% &rarr; -52.5<br>Total a pagar: 297.5</div>
// <!-- Ejemplo 2 -->
// <div style="background: #0f0f1a; padding: 20px 24px; border-radius: 16px; margin: 20px 0; font-family: monospace; font-size: 1.4rem; color: #a5d6ff; line-height: 1.6;">Cliente: Pedro Ruiz<br>Membres&iacute;a: REGULAR<br>Total original: 180.0<br><span style="color: #ffb4a2;">⚠️ No aplica descuento: compra m&iacute;nima es 200</span><br>Total a pagar: 180.0</div>
// <!-- Ejemplo 3 -->
// <div style="background: #0f0f1a; padding: 20px 24px; border-radius: 16px; margin: 20px 0; font-family: monospace; font-size: 1.4rem; color: #a5d6ff; line-height: 1.6;">Cliente: Luis Torres<br>Membres&iacute;a: GOLD<br>Total original: 400.0<br><span style="color: #ff6b6b;">❌ Error: tipo de membres&iacute;a no reconocido</span></div>
// </div>
// <!-- Línea decorativa inferior -->
// <div style="height: 5px; width: 110px; background: #7F52FF; border-radius: 5px; margin-top: 28px;">&nbsp;</div>
// </div>

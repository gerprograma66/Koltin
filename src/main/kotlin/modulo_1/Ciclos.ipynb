// %% [markdown]
// <div style="
//     font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, 'Helvetica Neue', Arial, sans-serif;
//     background: linear-gradient(135deg, #1e1e2f, #13111c);
//     padding: 20px 28px;
//     border-radius: 20px;
//     margin: 20px 0;
//     border: 1px solid rgba(156, 110, 255, 0.2);
//     box-shadow: 0 10px 25px rgba(0,0,0,0.5), inset 0 1px 0 rgba(255,255,255,0.05);
//     backdrop-filter: blur(2px);
// ">
//     <div style="
//         display: flex;
//         align-items: center;
//         gap: 14px;
//     ">
//         <div style="
//             background: linear-gradient(145deg, #7F52FF, #5a3fb5);
//             width: 44px;
//             height: 44px;
//             border-radius: 14px;
//             display: inline-flex;
//             align-items: center;
//             justify-content: center;
//             font-size: 24px;
//             box-shadow: 0 6px 14px rgba(127,82,255,0.4);
//         ">
//             🧠
//         </div>
//         <h3 style="
//             margin: 0;
//             font-size: 1.65rem;
//             font-weight: 600;
//             color: #E0D4FF;
//             letter-spacing: -0.3px;
//             text-shadow: 0 1px 2px rgba(0,0,0,0.3);
//         ">
//             Ciclos en Kotlin
//         </h3>
//     </div>
//     <div style="
//         height: 3px;
//         width: 80px;
//         background: linear-gradient(90deg, #9C6EFF, #7F52FF, #B39DDB);
//         border-radius: 3px;
//         margin-top: 15px;
//         box-shadow: 0 0 8px #7F52FF;
//     "></div>
// </div>

// %% [markdown]
// <div style="font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, 'Helvetica Neue', Arial, sans-serif; background: linear-gradient(135deg, #1e1e2f, #13111c); padding: 20px 28px; border-radius: 20px; margin: 20px 0; border: 1px solid rgba(156, 110, 255, 0.2); box-shadow: 0 10px 25px rgba(0,0,0,0.5), inset 0 1px 0 rgba(255,255,255,0.05); backdrop-filter: blur(2px);"><!-- Encabezado principal -->
// <div style="display: flex; align-items: center; gap: 12px; margin-bottom: 20px;">
// <div style="background: linear-gradient(145deg, #7F52FF, #5a3fb5); width: 42px; height: 42px; border-radius: 14px; display: inline-flex; align-items: center; justify-content: center; font-size: 22px; box-shadow: 0 4px 12px rgba(127,82,255,0.3);">🔷</div>
// <h3 style="margin: 0; font-size: 1.5rem; font-weight: 600; color: #e0d4ff; letter-spacing: -0.3px;"><code style="background: rgba(127, 82, 255, 0.2); padding: 4px 10px; border-radius: 8px; font-family: 'SF Mono', 'Fira Code', monospace; font-size: 1.4rem; color: #b39ddb; border: 1px solid rgba(127,82,255,0.3);">for</code></h3>
// </div>
// <details style="margin: 16px 0; background: rgba(255, 255, 255, 0.02); border-radius: 14px; padding: 0;">
// <summary style="cursor: pointer; padding: 12px 16px; font-weight: 600; color: #b39ddb; font-size: 0.95rem; background: rgba(127, 82, 255, 0.1); border-radius: 14px; transition: all 0.2s ease; list-style: none; display: inline-block; width: auto; user-select: none;">📖 Ver m&aacute;s</summary>
// <!-- Lista de características -->
// <ul style="margin: 0 0 16px 0; padding-left: 24px; color: #b8b0e0; font-size: 0.92rem; line-height: 1.65;">
// <li style="margin: 12px 0; list-style-type: '🔄 ';">Itera sobre cualquier elemento que sea <strong style="color: #e0d4ff;">iterable</strong>: rangos, listas, arreglos, mapas, etc.</li>
// <li style="margin: 12px 0; list-style-type: '📌 ';">Utiliza la palabra reservada <strong style="color: #ffd966;"><code style="background: rgba(127, 82, 255, 0.25); padding: 2px 8px; border-radius: 6px; font-family: monospace; color: #ffd966;">in</code></strong> para indicar sobre qu&eacute; elemento se itera.</li>
// <li style="margin: 12px 0; list-style-type: '🔢 ';">Puede iterar con el <strong style="color: #e0d4ff;">&iacute;ndice y el valor</strong> al mismo tiempo usando <code style="background: rgba(127, 82, 255, 0.2); padding: 2px 6px; border-radius: 6px; font-family: monospace; color: #b39ddb;">withIndex()</code>.</li>
// <li style="margin: 12px 0; list-style-type: '⬇️ ';">Puede iterar sobre <strong style="color: #e0d4ff;">rangos descendentes</strong> con <code style="background: rgba(127, 82, 255, 0.2); padding: 2px 6px; border-radius: 6px; font-family: monospace; color: #b39ddb;">downTo</code> y con pasos personalizados con <code style="background: rgba(127, 82, 255, 0.2); padding: 2px 6px; border-radius: 6px; font-family: monospace; color: #b39ddb;">step</code>.</li>
// <li style="margin: 12px 0; list-style-type: '🔒 ';">La variable de iteraci&oacute;n es de <strong style="color: #e0d4ff;">solo lectura</strong>, no se puede modificar dentro del bucle.</li>
// <li style="margin: 12px 0; list-style-type: '🏁 ';">Se detiene autom&aacute;ticamente al <strong style="color: #e0d4ff;">llegar al final</strong> del iterable, no necesita condici&oacute;n de parada expl&iacute;cita.</li>
// <li style="margin: 12px 0; list-style-type: '⚠️ ';"><strong style="color: #ffb4a2;">No existe</strong> la versi&oacute;n cl&aacute;sica de Java/C <code style="background: rgba(127, 82, 255, 0.2); padding: 2px 6px; border-radius: 6px; font-family: monospace; color: #b39ddb;">for(int i=0; i&lt;10; i++)</code>, se reemplaza con rangos.</li>
// </ul>
// <!-- Línea decorativa inferior -->
// <div style="height: 3px; width: 60px; background: linear-gradient(90deg, #9C6EFF, #7F52FF, #B39DDB); border-radius: 3px; margin-top: 8px; box-shadow: 0 0 8px #7F52FF;">&nbsp;</div>
// </details>
// </div>

// %% [markdown]
// <div style="font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, 'Helvetica Neue', Arial, sans-serif; background: linear-gradient(135deg, #1e1e2f, #13111c); padding: 20px 28px; border-radius: 20px; margin: 20px 0; border: 1px solid rgba(156, 110, 255, 0.2); box-shadow: 0 10px 25px rgba(0,0,0,0.5), inset 0 1px 0 rgba(255,255,255,0.05); backdrop-filter: blur(2px);"><!-- Encabezado principal -->
// <div style="display: flex; align-items: center; gap: 12px; margin-bottom: 20px;">
// <div style="background: linear-gradient(145deg, #7F52FF, #5a3fb5); width: 42px; height: 42px; border-radius: 14px; display: inline-flex; align-items: center; justify-content: center; font-size: 22px; box-shadow: 0 4px 12px rgba(127,82,255,0.3);">🔷</div>
// <h3 style="margin: 0; font-size: 1.5rem; font-weight: 600; color: #e0d4ff; letter-spacing: -0.3px;"><code style="background: rgba(127, 82, 255, 0.2); padding: 4px 10px; border-radius: 8px; font-family: 'SF Mono', 'Fira Code', monospace; font-size: 1.4rem; color: #b39ddb; border: 1px solid rgba(127,82,255,0.3);">while</code></h3>
// </div>
// <details style="margin: 16px 0; background: rgba(255, 255, 255, 0.02); border-radius: 14px; padding: 0;">
// <summary style="cursor: pointer; padding: 12px 16px; font-weight: 600; color: #b39ddb; font-size: 0.95rem; background: rgba(127, 82, 255, 0.1); border-radius: 14px; transition: all 0.2s ease; list-style: none; display: inline-block; width: auto; user-select: none;">📖 Ver m&aacute;s</summary>
// <!-- Lista de características -->
// <ul style="margin: 0 0 16px 0; padding-left: 24px; color: #b8b0e0; font-size: 0.92rem; line-height: 1.65;">
// <li style="margin: 12px 0; list-style-type: '⏳ ';">Eval&uacute;a la condici&oacute;n <strong style="color: #ffd966;">antes</strong> de ejecutar el bloque, por lo que puede <strong style="color: #ffb4a2;">no ejecutarse nunca</strong> si la condici&oacute;n es falsa desde el inicio.</li>
// <li style="margin: 12px 0; list-style-type: '⚖️ ';">La condici&oacute;n debe ser una <strong style="color: #e0d4ff;">expresi&oacute;n booleana</strong>.</li>
// <li style="margin: 12px 0; list-style-type: '❓ ';">Es ideal cuando <strong style="color: #e0d4ff;">no se sabe de antemano</strong> cu&aacute;ntas veces se va a repetir el bloque.</li>
// <li style="margin: 12px 0; list-style-type: '📦 ';">La variable de control debe <strong style="color: #e0d4ff;">declararse fuera</strong> del bucle y modificarse dentro para evitar bucles infinitos.</li>
// <li style="margin: 12px 0; list-style-type: '⚠️ ';">Si la condici&oacute;n nunca se vuelve falsa, genera un <strong style="color: #ffb4a2;">bucle infinito</strong>.</li>
// </ul>
// <!-- Línea decorativa inferior -->
// <div style="height: 3px; width: 60px; background: linear-gradient(90deg, #9C6EFF, #7F52FF, #B39DDB); border-radius: 3px; margin-top: 8px; box-shadow: 0 0 8px #7F52FF;">&nbsp;</div>
// </details>
// </div>

// %% [markdown]
// <div style="font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, 'Helvetica Neue', Arial, sans-serif; background: linear-gradient(135deg, #1e1e2f, #13111c); padding: 20px 28px; border-radius: 20px; margin: 20px 0; border: 1px solid rgba(156, 110, 255, 0.2); box-shadow: 0 10px 25px rgba(0,0,0,0.5), inset 0 1px 0 rgba(255,255,255,0.05); backdrop-filter: blur(2px);"><!-- Encabezado principal -->
// <div style="display: flex; align-items: center; gap: 12px; margin-bottom: 20px;">
// <div style="background: linear-gradient(145deg, #7F52FF, #5a3fb5); width: 42px; height: 42px; border-radius: 14px; display: inline-flex; align-items: center; justify-content: center; font-size: 22px; box-shadow: 0 4px 12px rgba(127,82,255,0.3);">🔷</div>
// <h3 style="margin: 0; font-size: 1.5rem; font-weight: 600; color: #e0d4ff; letter-spacing: -0.3px;"><code style="background: rgba(127, 82, 255, 0.2); padding: 4px 10px; border-radius: 8px; font-family: 'SF Mono', 'Fira Code', monospace; font-size: 1.4rem; color: #b39ddb; border: 1px solid rgba(127,82,255,0.3);">do-while</code></h3>
// </div>
// <details style="margin: 16px 0; background: rgba(255, 255, 255, 0.02); border-radius: 14px; padding: 0;">
// <summary style="cursor: pointer; padding: 12px 16px; font-weight: 600; color: #b39ddb; font-size: 0.95rem; background: rgba(127, 82, 255, 0.1); border-radius: 14px; transition: all 0.2s ease; list-style: none; display: inline-block; width: auto; user-select: none;">📖 Ver m&aacute;s</summary>
// <!-- Lista de características -->
// <ul style="margin: 0 0 16px 0; padding-left: 24px; color: #b8b0e0; font-size: 0.92rem; line-height: 1.65;">
// <li style="margin: 12px 0; list-style-type: '🔄 ';">Eval&uacute;a la condici&oacute;n <strong style="color: #ffd966;">despu&eacute;s</strong> de ejecutar el bloque, garantizando que se ejecute <strong style="color: #a5d6ff;">al menos una vez</strong>.</li>
// <li style="margin: 12px 0; list-style-type: '⚖️ ';">La condici&oacute;n tambi&eacute;n debe ser una <strong style="color: #e0d4ff;">expresi&oacute;n booleana</strong>.</li>
// <li style="margin: 12px 0; list-style-type: '✅ ';">Es &uacute;til cuando se necesita ejecutar una acci&oacute;n <strong style="color: #e0d4ff;">antes de verificar</strong> si se debe repetir.</li>
// <li style="margin: 12px 0; list-style-type: '⚠️ ';">Al igual que <code style="background: rgba(127, 82, 255, 0.2); padding: 2px 6px; border-radius: 6px; font-family: monospace; color: #b39ddb;">while</code>, requiere que la variable de control se <strong style="color: #e0d4ff;">modifique dentro</strong> del bloque para evitar bucles infinitos.</li>
// <li style="margin: 12px 0; list-style-type: '🏆 ';">Es el &uacute;nico bucle en Kotlin que <strong style="color: #ffd966;">garantiza una ejecuci&oacute;n m&iacute;nima</strong>.</li>
// </ul>
// <!-- Línea decorativa inferior -->
// <div style="height: 3px; width: 60px; background: linear-gradient(90deg, #9C6EFF, #7F52FF, #B39DDB); border-radius: 3px; margin-top: 8px; box-shadow: 0 0 8px #7F52FF;">&nbsp;</div>
// </details>
// </div>

// %% [markdown]
// <div style="font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, 'Helvetica Neue', Arial, sans-serif; background: linear-gradient(135deg, #1e1e2f, #13111c); padding: 20px 28px; border-radius: 20px; margin: 20px 0; border: 1px solid rgba(156, 110, 255, 0.2); box-shadow: 0 10px 25px rgba(0,0,0,0.5), inset 0 1px 0 rgba(255,255,255,0.05); backdrop-filter: blur(2px);"><!-- Encabezado principal -->
// <div style="display: flex; align-items: center; gap: 12px; margin-bottom: 20px;">
// <div style="background: linear-gradient(145deg, #7F52FF, #5a3fb5); width: 42px; height: 42px; border-radius: 14px; display: inline-flex; align-items: center; justify-content: center; font-size: 22px; box-shadow: 0 4px 12px rgba(127,82,255,0.3);">🔷</div>
// <h3 style="margin: 0; font-size: 1.5rem; font-weight: 600; color: #e0d4ff; letter-spacing: -0.3px;">Control de bucles: <code style="background: rgba(127, 82, 255, 0.2); padding: 4px 8px; border-radius: 8px; font-family: 'SF Mono', 'Fira Code', monospace; font-size: 1.3rem; color: #b39ddb; border: 1px solid rgba(127,82,255,0.3);">break</code>, <code style="background: rgba(127, 82, 255, 0.2); padding: 4px 8px; border-radius: 8px; font-family: 'SF Mono', 'Fira Code', monospace; font-size: 1.3rem; color: #b39ddb; border: 1px solid rgba(127,82,255,0.3);">continue</code> y Labels</h3>
// </div>
// <details style="margin: 16px 0; background: rgba(255, 255, 255, 0.02); border-radius: 14px; padding: 0;">
// <summary style="cursor: pointer; padding: 12px 16px; font-weight: 600; color: #b39ddb; font-size: 0.95rem; background: rgba(127, 82, 255, 0.1); border-radius: 14px; transition: all 0.2s ease; list-style: none; display: inline-block; width: auto; user-select: none;">📖 Ver m&aacute;s</summary>
// <!-- Sección: break -->
// <div style="background: rgba(255, 255, 255, 0.03); border-left: 3px solid #7F52FF; padding: 12px 16px; border-radius: 12px; margin: 16px 0;">
// <p style="margin: 0 0 8px 0;"><strong style="color: #b39ddb;"> <code style="background: rgba(127, 82, 255, 0.25); padding: 2px 8px; border-radius: 6px; font-family: monospace; color: #b39ddb;">break</code>: </strong></p>
// <ul style="margin: 0; padding-left: 24px; color: #b8b0e0; font-size: 0.92rem; line-height: 1.65;">
// <li style="margin: 8px 0; list-style-type: '🛑 ';"><strong style="color: #ffb4a2;">Detiene completamente</strong> el bucle en el que se encuentra.</li>
// <li style="margin: 8px 0; list-style-type: '📦 ';">En bucles anidados, por defecto solo afecta al bucle <strong style="color: #e0d4ff;">m&aacute;s interno</strong>.</li>
// </ul>
// </div>
// <!-- Sección: continue -->
// <div style="background: rgba(255, 255, 255, 0.03); border-left: 3px solid #7F52FF; padding: 12px 16px; border-radius: 12px; margin: 16px 0;">
// <p style="margin: 0 0 8px 0;"><strong style="color: #b39ddb;"> <code style="background: rgba(127, 82, 255, 0.25); padding: 2px 8px; border-radius: 6px; font-family: monospace; color: #b39ddb;">continue</code>: </strong></p>
// <ul style="margin: 0; padding-left: 24px; color: #b8b0e0; font-size: 0.92rem; line-height: 1.65;">
// <li style="margin: 8px 0; list-style-type: '⏩ ';"><strong style="color: #a5d6ff;">Salta la iteraci&oacute;n actual</strong> y pasa directamente a la siguiente.</li>
// <li style="margin: 8px 0; list-style-type: '📦 ';">Al igual que <code style="background: rgba(127, 82, 255, 0.2); padding: 2px 6px; border-radius: 6px; font-family: monospace; color: #b39ddb;">break</code>, por defecto solo afecta al bucle <strong style="color: #e0d4ff;">m&aacute;s interno</strong>.</li>
// </ul>
// </div>
// <!-- Sección: Labels -->
// <div style="background: rgba(255, 255, 255, 0.03); border-left: 3px solid #7F52FF; padding: 12px 16px; border-radius: 12px; margin: 16px 0;">
// <p style="margin: 0 0 8px 0;"><strong style="color: #b39ddb;">Labels (<code style="background: rgba(127, 82, 255, 0.25); padding: 2px 6px; border-radius: 6px; font-family: monospace; color: #ffd966;">@</code>):</strong></p>
// <ul style="margin: 0; padding-left: 24px; color: #b8b0e0; font-size: 0.92rem; line-height: 1.65;">
// <li style="margin: 8px 0; list-style-type: '🏷️ ';">Permiten nombrar un bucle para que <code style="background: rgba(127, 82, 255, 0.2); padding: 2px 6px; border-radius: 6px; font-family: monospace; color: #b39ddb;">break</code> o <code style="background: rgba(127, 82, 255, 0.2); padding: 2px 6px; border-radius: 6px; font-family: monospace; color: #b39ddb;">continue</code> afecten a un bucle <strong style="color: #e0d4ff;">externo espec&iacute;fico</strong>.</li>
// <li style="margin: 8px 0; list-style-type: '🎯 ';">Son especialmente &uacute;tiles en <strong style="color: #e0d4ff;">bucles anidados</strong> donde se necesita salir de m&aacute;s de un nivel.</li>
// <li style="margin: 8px 0; list-style-type: '✍️ ';">Se declaran escribiendo un nombre seguido de <code style="background: rgba(127, 82, 255, 0.25); padding: 2px 6px; border-radius: 6px; font-family: monospace; color: #ffd966;">@</code> antes del bucle.</li>
// </ul>
// </div>
// <!-- Línea decorativa inferior -->
// <div style="height: 3px; width: 60px; background: linear-gradient(90deg, #9C6EFF, #7F52FF, #B39DDB); border-radius: 3px; margin-top: 8px; box-shadow: 0 0 8px #7F52FF;">&nbsp;</div>
// </details>
// </div>

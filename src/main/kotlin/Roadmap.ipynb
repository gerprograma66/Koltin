// %% [markdown]
// <div style="font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, 'Helvetica Neue', sans-serif; max-width: 1000px; margin: 0 auto; background: linear-gradient(145deg, #0a0f1e 0%, #0c1222 100%); border-radius: 2rem; padding: 1.8rem 1.5rem 2rem 1.5rem; color: #eef4ff; box-shadow: 0 20px 35px -12px rgba(0,0,0,0.4); border: 1px solid rgba(78,105,165,0.3); font-size: 1.1rem;">
// <h1 style="font-size: 2.09rem; font-weight: bold; color: #ffffff; text-align: center; margin: 0 0 0.25rem 0;">📘 Roadmap Lineal &middot; Aprende Kotlin</h1>
// <div style="text-align: center; color: #8d9fcf; margin-bottom: 1.8rem; border-bottom: 1px dashed #2a3650; display: inline-block; width: auto; margin-left: auto; margin-right: auto; padding-bottom: 0.4rem; font-weight: 500; font-size: 1.1rem;">🚀</div>
// <div style="position: relative; display: flex; flex-direction: column; gap: 0.9rem;"><!-- Línea vertical decorativa (timeline) -->
// <div style="position: absolute; left: 1.8rem; top: 1rem; bottom: 1rem; width: 3px; background: linear-gradient(180deg, #3b5b9b, #7f9fdf, #3b5b9b); border-radius: 4px; box-shadow: 0 0 6px rgba(79,128,255,0.4); z-index: 0;">&nbsp;</div>
// <!-- Etapa 1 -->
// <div style="position: relative; z-index: 2; background: rgba(12,20,35,0.85); backdrop-filter: blur(4px); border-radius: 1.5rem; margin-left: 1.8rem; margin-right: 0.2rem; padding: 0.9rem 1rem 0.9rem 2rem; border: 1px solid rgba(72,110,180,0.5); transition: 0.2s;">
// <div style="position: absolute; left: -1.7rem; top: 0.7rem; width: 2.4rem; height: 2.4rem; background: linear-gradient(145deg, #1f2c48, #111a2c); border-radius: 60%; display: flex; align-items: center; justify-content: center; font-weight: bold; font-size: 1.1rem; border: 2px solid #5675c9; color: #cddcff;">1</div>
// <div style="display: flex; flex-wrap: wrap; align-items: baseline; gap: 0.6rem; margin-bottom: 0.3rem;"><span style="font-size: 1.485rem; font-weight: bold; color: #ffffff;">Fundamentos de programaci&oacute;n</span></div>
// <div style="color: #cad2f0; font-size: 0.968rem; line-height: 1.45;">Cimientos s&oacute;lidos: variables, tipos de datos, condicionales, bucles, input/output.</div>
// <div style="display: flex; flex-wrap: wrap; gap: 0.55rem; margin-top: 0.7rem;"><span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff; border: 0.5px solid #4f6fb0;">Variables &amp; Tipos</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff; border: 0.5px solid #4f6fb0;">println / readLine</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff; border: 0.5px solid #4f6fb0;">if / else / when</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff; border: 0.5px solid #4f6fb0;">for / while</span></div>
// </div>
// <!-- Etapa 2 -->
// <div style="position: relative; z-index: 2; background: rgba(12,20,35,0.85); backdrop-filter: blur(4px); border-radius: 1.5rem; margin-left: 1.8rem; margin-right: 0.2rem; padding: 0.9rem 1rem 0.9rem 2rem; border: 1px solid rgba(72,110,180,0.5);">
// <div style="position: absolute; left: -1.7rem; top: 0.7rem; width: 2.4rem; height: 2.4rem; background: linear-gradient(145deg, #1f2c48, #111a2c); border-radius: 60%; display: flex; align-items: center; justify-content: center; font-weight: bold; font-size: 1.1rem; border: 2px solid #5675c9; color: #cddcff;">2</div>
// <div style="display: flex; flex-wrap: wrap; align-items: baseline; gap: 0.6rem; margin-bottom: 0.3rem;"><span style="font-size: 1.485rem; font-weight: bold; color: #ffffff;">Conceptos b&aacute;sicos de Kotlin</span></div>
// <div style="color: #cad2f0; font-size: 0.968rem;">Null safety, <code style="background: #1e2a44; padding: 0.1rem 0.3rem; border-radius: 6px;">val/var</code>, type inference, strings templates, rangos y funciones.</div>
// <div style="display: flex; flex-wrap: wrap; gap: 0.55rem; margin-top: 0.7rem;"><span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">Null safety (?, !! ,?:)</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">String templates</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">Rangos (1..10)</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">Funciones b&aacute;sicas</span></div>
// </div>
// <!-- Etapa 3 -->
// <div style="position: relative; z-index: 2; background: rgba(12,20,35,0.85); backdrop-filter: blur(4px); border-radius: 1.5rem; margin-left: 1.8rem; margin-right: 0.2rem; padding: 0.9rem 1rem 0.9rem 2rem; border: 1px solid rgba(72,110,180,0.5);">
// <div style="position: absolute; left: -1.7rem; top: 0.7rem; width: 2.4rem; height: 2.4rem; background: linear-gradient(145deg, #1f2c48, #111a2c); border-radius: 60%; display: flex; align-items: center; justify-content: center; font-weight: bold; font-size: 1.1rem; border: 2px solid #5675c9; color: #cddcff;">3</div>
// <div><span style="font-size: 1.485rem; font-weight: bold; color: #ffffff;">Funciones avanzadas y Lambdas</span></div>
// <div style="color: #cad2f0; font-size: 0.968rem;">Funciones de orden superior, lambdas, &aacute;mbitos: let, apply, run, with, also.</div>
// <div style="display: flex; flex-wrap: wrap; gap: 0.55rem; margin-top: 0.7rem;"><span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">Lambda expressions</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">Funciones inline</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">let / apply / run</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">Funciones infijas</span></div>
// </div>
// <!-- Etapa 4 -->
// <div style="position: relative; z-index: 2; background: rgba(12,20,35,0.85); backdrop-filter: blur(4px); border-radius: 1.5rem; margin-left: 1.8rem; margin-right: 0.2rem; padding: 0.9rem 1rem 0.9rem 2rem; border: 1px solid rgba(72,110,180,0.5);">
// <div style="position: absolute; left: -1.7rem; top: 0.7rem; width: 2.4rem; height: 2.4rem; background: linear-gradient(145deg, #1f2c48, #111a2c); border-radius: 60%; display: flex; align-items: center; justify-content: center; font-weight: bold; font-size: 1.1rem; border: 2px solid #5675c9; color: #cddcff;">4</div>
// <div><span style="font-size: 1.485rem; font-weight: bold; color: #ffffff;">Colecciones y operaciones funcionales</span></div>
// <div style="color: #cad2f0; font-size: 0.968rem;">List, Set, Map, filter, map, flatMap, reduce, fold, Sequences.</div>
// <div style="display: flex; flex-wrap: wrap; gap: 0.55rem; margin-top: 0.7rem;"><span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">List / Set / Map</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">filter &amp; map</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">flatMap / reduce</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">Sequences</span></div>
// </div>
// <!-- Etapa 5 -->
// <div style="position: relative; z-index: 2; background: rgba(12,20,35,0.85); backdrop-filter: blur(4px); border-radius: 1.5rem; margin-left: 1.8rem; margin-right: 0.2rem; padding: 0.9rem 1rem 0.9rem 2rem; border: 1px solid rgba(72,110,180,0.5);">
// <div style="position: absolute; left: -1.7rem; top: 0.7rem; width: 2.4rem; height: 2.4rem; background: linear-gradient(145deg, #1f2c48, #111a2c); border-radius: 60%; display: flex; align-items: center; justify-content: center; font-weight: bold; font-size: 1.1rem; border: 2px solid #5675c9; color: #cddcff;">5</div>
// <div><span style="font-size: 1.485rem; font-weight: bold; color: #ffffff;">POO en Kotlin</span></div>
// <div style="color: #cad2f0; font-size: 0.968rem;">Clases, herencia, modificadores, data classes, sealed classes, object.</div>
// <div style="display: flex; flex-wrap: wrap; gap: 0.55rem; margin-top: 0.7rem;"><span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">Constructor / propiedades</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">Herencia</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">Data classes</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">Sealed classes</span></div>
// </div>
// <!-- Etapa 6 -->
// <div style="position: relative; z-index: 2; background: rgba(12,20,35,0.85); backdrop-filter: blur(4px); border-radius: 1.5rem; margin-left: 1.8rem; margin-right: 0.2rem; padding: 0.9rem 1rem 0.9rem 2rem; border: 1px solid rgba(72,110,180,0.5);">
// <div style="position: absolute; left: -1.7rem; top: 0.7rem; width: 2.4rem; height: 2.4rem; background: linear-gradient(145deg, #1f2c48, #111a2c); border-radius: 60%; display: flex; align-items: center; justify-content: center; font-weight: bold; font-size: 1.1rem; border: 2px solid #5675c9; color: #cddcff;">6</div>
// <div><span style="font-size: 1.485rem; font-weight: bold; color: #ffffff;">Conceptos intermedios</span></div>
// <div style="color: #cad2f0; font-size: 0.968rem;">Extension functions, generics b&aacute;sicos, lateinit, lazy, destructuring.</div>
// <div style="display: flex; flex-wrap: wrap; gap: 0.55rem; margin-top: 0.7rem;"><span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">Extension functions</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">Generics (in/out)</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">lateinit / lazy</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">Destructuring</span></div>
// </div>
// <!-- Etapa 7 -->
// <div style="position: relative; z-index: 2; background: rgba(12,20,35,0.85); backdrop-filter: blur(4px); border-radius: 1.5rem; margin-left: 1.8rem; margin-right: 0.2rem; padding: 0.9rem 1rem 0.9rem 2rem; border: 1px solid rgba(72,110,180,0.5);">
// <div style="position: absolute; left: -1.7rem; top: 0.7rem; width: 2.4rem; height: 2.4rem; background: linear-gradient(145deg, #1f2c48, #111a2c); border-radius: 60%; display: flex; align-items: center; justify-content: center; font-weight: bold; font-size: 1.1rem; border: 2px solid #5675c9; color: #cddcff;">7</div>
// <div><span style="font-size: 1.485rem; font-weight: bold; color: #ffffff;">Manejo de errores</span></div>
// <div style="color: #cad2f0; font-size: 0.968rem;">try-catch-finally, runCatching, Result&lt;T&gt;.</div>
// <div style="display: flex; flex-wrap: wrap; gap: 0.55rem; margin-top: 0.7rem;"><span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">try-catch</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">runCatching</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">Result type</span></div>
// </div>
// <!-- Etapa 8 -->
// <div style="position: relative; z-index: 2; background: rgba(12,20,35,0.85); backdrop-filter: blur(4px); border-radius: 1.5rem; margin-left: 1.8rem; margin-right: 0.2rem; padding: 0.9rem 1rem 0.9rem 2rem; border: 1px solid rgba(72,110,180,0.5);">
// <div style="position: absolute; left: -1.7rem; top: 0.7rem; width: 2.4rem; height: 2.4rem; background: linear-gradient(145deg, #1f2c48, #111a2c); border-radius: 60%; display: flex; align-items: center; justify-content: center; font-weight: bold; font-size: 1.1rem; border: 2px solid #5675c9; color: #cddcff;">8</div>
// <div><span style="font-size: 1.485rem; font-weight: bold; color: #ffffff;">Corrutinas (asincron&iacute;a moderna)</span></div>
// <div style="color: #cad2f0; font-size: 0.968rem;">launch, async, suspend functions, Dispatchers, Flow, StateFlow.</div>
// <div style="display: flex; flex-wrap: wrap; gap: 0.55rem; margin-top: 0.7rem;"><span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">CoroutineScope</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">suspend functions</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">Flow API</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">StateFlow</span></div>
// </div>
// <!-- Etapa 9: especialización -->
// <div style="position: relative; z-index: 2; background: rgba(12,20,35,0.85); backdrop-filter: blur(4px); border-radius: 1.5rem; margin-left: 1.8rem; margin-right: 0.2rem; padding: 0.9rem 1rem 0.9rem 2rem; border: 1px solid rgba(72,110,180,0.5);">
// <div style="position: absolute; left: -1.7rem; top: 0.7rem; width: 2.4rem; height: 2.4rem; background: linear-gradient(145deg, #1f2c48, #111a2c); border-radius: 60%; display: flex; align-items: center; justify-content: center; font-weight: bold; font-size: 1.1rem; border: 2px solid #5675c9; color: #cddcff;">9</div>
// <div><span style="font-size: 1.485rem; font-weight: bold; color: #ffffff;">Kotlin en el entorno real</span></div>
// <div style="color: #cad2f0; font-size: 0.968rem;">Backend (Spring + Ktor) &middot; Android + Compose &middot; KMP &middot; Kotlin/JS</div>
// <div style="margin-top: 0.6rem; background: #0f1829; border-radius: 1rem; padding: 0.35rem 0.9rem; font-size: 0.77rem; border-left: 3px solid #6290ff; color: #abb9e6;">🧩 Gradle, Exposed, Room, Retrofit, expect/actual multiplataforma</div>
// </div>
// <!-- Etapa 10: proyectos -->
// <div style="position: relative; z-index: 2; background: rgba(12,20,35,0.85); backdrop-filter: blur(4px); border-radius: 1.5rem; margin-left: 1.8rem; margin-right: 0.2rem; padding: 0.9rem 1rem 0.9rem 2rem; border: 1px solid rgba(72,110,180,0.5);">
// <div style="position: absolute; left: -1.7rem; top: 0.7rem; width: 2.4rem; height: 2.4rem; background: linear-gradient(145deg, #1f2c48, #111a2c); border-radius: 60%; display: flex; align-items: center; justify-content: center; font-weight: bold; font-size: 1.1rem; border: 2px solid #5675c9; color: #cddcff;">10</div>
// <div><span style="font-size: 1.485rem; font-weight: bold; color: #ffffff;">Proyectos pr&aacute;cticos &amp; portafolio</span></div>
// <div style="color: #cad2f0; font-size: 0.968rem;">Calculadora, app de tareas con Room, CLI, backend con Spring, app Android con Compose.</div>
// <div style="display: flex; flex-wrap: wrap; gap: 0.55rem; margin-top: 0.7rem;"><span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">Calculadora + historial</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">App Room + corrutinas</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">Backend Spring</span> <span style="background: rgba(45,70,115,0.5); border-radius: 40px; padding: 0.22rem 0.77rem; font-size: 0.77rem; color: #bfd6ff;">Android Compose</span></div>
// </div>
// </div>
// <hr style="margin: 1.5rem 0 0.8rem; border-color: #253458;">
// <div style="display: flex; flex-wrap: wrap; justify-content: space-between; align-items: center; gap: 0.8rem; font-size: 0.88rem;">
// <div>🧠 <strong>Roadmap lineal</strong> &mdash; sigue el orden recomendado. Cada bloque es prerrequisito del siguiente.</div>
// <div style="background: #101a30; border-radius: 28px; padding: 0.22rem 1.1rem; color: #bfd6ff; font-size: 0.88rem;">⚡ Practica con c&oacute;digo Kotlin en cada etapa</div>
// </div>
// <div style="text-align: center; margin-top: 1rem; font-size: 0.77rem; color: #6877a5;">📌 Documentaci&oacute;n oficial: kotlinlang.org &middot; Comunidad Kotlin &middot; Proyectos pr&aacute;cticos diarios</div>
// </div>

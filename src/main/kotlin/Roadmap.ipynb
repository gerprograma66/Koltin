// %% [markdown]
// <div style="font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, 'Helvetica Neue', sans-serif; max-width: 1400px; margin: 0 auto; background: linear-gradient(145deg, #0a0f1e 0%, #0c1222 100%); border-radius: 3rem; padding: 2.8rem 2.5rem 3rem 2.5rem; color: #eef4ff; box-shadow: 0 25px 45px -12px rgba(0,0,0,0.5); border: 2px solid rgba(78,105,165,0.5); font-size: 1.8rem;">
// <h1 style="font-size: 3.8rem; font-weight: bold; color: #ffffff; text-align: center; margin: 0 0 0.8rem 0;">📘 Roadmap Lineal &middot; Aprende Kotlin</h1>
// <div style="text-align: center; color: #8d9fcf; margin-bottom: 2.8rem; border-bottom: 2px dashed #2a3650; display: inline-block; width: auto; margin-left: auto; margin-right: auto; padding-bottom: 0.8rem; font-weight: 600; font-size: 2rem;"></div>
// <div style="position: relative; display: flex; flex-direction: column; gap: 1.8rem;"><!-- Línea vertical decorativa (timeline) más gruesa -->
// <div style="position: absolute; left: 2.8rem; top: 1rem; bottom: 1rem; width: 6px; background: linear-gradient(180deg, #3b5b9b, #7f9fdf, #3b5b9b); border-radius: 6px; box-shadow: 0 0 10px rgba(79,128,255,0.6); z-index: 0;">&nbsp;</div>
// <!-- Etapa 1 -->
// <div style="position: relative; z-index: 2; background: rgba(12,20,35,0.85); backdrop-filter: blur(4px); border-radius: 2.5rem; margin-left: 2.8rem; margin-right: 0.5rem; padding: 1.8rem 2rem 1.8rem 3rem; border: 2px solid rgba(72,110,180,0.7);">
// <div style="position: absolute; left: -2.4rem; top: 1.2rem; width: 3.6rem; height: 3.6rem; background: linear-gradient(145deg, #1f2c48, #111a2c); border-radius: 50%; display: flex; align-items: center; justify-content: center; font-weight: bold; font-size: 2rem; border: 3px solid #5675c9; color: #cddcff;">1</div>
// <div style="display: flex; flex-wrap: wrap; align-items: baseline; gap: 1rem; margin-bottom: 0.8rem;"><span style="font-size: 2.6rem; font-weight: bold; color: #ffffff;">Fundamentos de programaci&oacute;n</span></div>
// <div style="color: #cad2f0; font-size: 1.8rem; line-height: 1.5;">Cimientos s&oacute;lidos: variables, tipos de datos, condicionales, bucles, input/output.</div>
// <div style="display: flex; flex-wrap: wrap; gap: 1rem; margin-top: 1.2rem;"><span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem; color: #bfd6ff; border: 1px solid #4f6fb0;">Variables &amp; Tipos</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem; color: #bfd6ff; border: 1px solid #4f6fb0;">println / readLine</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem; color: #bfd6ff; border: 1px solid #4f6fb0;">if / else / when</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem; color: #bfd6ff; border: 1px solid #4f6fb0;">for / while</span></div>
// </div>
// <!-- Etapa 2 -->
// <div style="position: relative; z-index: 2; background: rgba(12,20,35,0.85); backdrop-filter: blur(4px); border-radius: 2.5rem; margin-left: 2.8rem; margin-right: 0.5rem; padding: 1.8rem 2rem 1.8rem 3rem; border: 2px solid rgba(72,110,180,0.7);">
// <div style="position: absolute; left: -2.4rem; top: 1.2rem; width: 3.6rem; height: 3.6rem; background: linear-gradient(145deg, #1f2c48, #111a2c); border-radius: 50%; display: flex; align-items: center; justify-content: center; font-weight: bold; font-size: 2rem; border: 3px solid #5675c9; color: #cddcff;">2</div>
// <div style="display: flex; flex-wrap: wrap; align-items: baseline; gap: 1rem; margin-bottom: 0.8rem;"><span style="font-size: 2.6rem; font-weight: bold; color: #ffffff;">Conceptos b&aacute;sicos de Kotlin</span></div>
// <div style="color: #cad2f0; font-size: 1.8rem;">Null safety, <code style="background: #1e2a44; padding: 0.2rem 0.6rem; border-radius: 10px; font-size: 1.6rem;">val/var</code>, type inference, strings templates, rangos y funciones.</div>
// <div style="display: flex; flex-wrap: wrap; gap: 1rem; margin-top: 1.2rem;"><span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem; color: #bfd6ff;">Null safety (?, !! ,?:)</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem; color: #bfd6ff;">String templates</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem; color: #bfd6ff;">Rangos (1..10)</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem; color: #bfd6ff;">Funciones b&aacute;sicas</span></div>
// </div>
// <!-- Etapa 3 -->
// <div style="position: relative; z-index: 2; background: rgba(12,20,35,0.85); backdrop-filter: blur(4px); border-radius: 2.5rem; margin-left: 2.8rem; margin-right: 0.5rem; padding: 1.8rem 2rem 1.8rem 3rem; border: 2px solid rgba(72,110,180,0.7);">
// <div style="position: absolute; left: -2.4rem; top: 1.2rem; width: 3.6rem; height: 3.6rem; background: linear-gradient(145deg, #1f2c48, #111a2c); border-radius: 50%; display: flex; align-items: center; justify-content: center; font-weight: bold; font-size: 2rem; border: 3px solid #5675c9; color: #cddcff;">3</div>
// <div><span style="font-size: 2.6rem; font-weight: bold; color: #ffffff;">Funciones avanzadas y Lambdas</span></div>
// <div style="color: #cad2f0; font-size: 1.8rem;">Funciones de orden superior, lambdas, &aacute;mbitos: let, apply, run, with, also.</div>
// <div style="display: flex; flex-wrap: wrap; gap: 1rem; margin-top: 1.2rem;"><span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem; color: #bfd6ff;">Lambda expressions</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem; color: #bfd6ff;">Funciones inline</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem; color: #bfd6ff;">let / apply / run</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem; color: #bfd6ff;">Funciones infijas</span></div>
// </div>
// <!-- Etapa 4 -->
// <div style="position: relative; z-index: 2; background: rgba(12,20,35,0.85); backdrop-filter: blur(4px); border-radius: 2.5rem; margin-left: 2.8rem; margin-right: 0.5rem; padding: 1.8rem 2rem 1.8rem 3rem; border: 2px solid rgba(72,110,180,0.7);">
// <div style="position: absolute; left: -2.4rem; top: 1.2rem; width: 3.6rem; height: 3.6rem; background: linear-gradient(145deg, #1f2c48, #111a2c); border-radius: 50%; display: flex; align-items: center; justify-content: center; font-weight: bold; font-size: 2rem; border: 3px solid #5675c9; color: #cddcff;">4</div>
// <div><span style="font-size: 2.6rem; font-weight: bold; color: #ffffff;">Colecciones y operaciones funcionales</span></div>
// <div style="color: #cad2f0; font-size: 1.8rem;">List, Set, Map, filter, map, flatMap, reduce, fold, Sequences.</div>
// <div style="display: flex; flex-wrap: wrap; gap: 1rem; margin-top: 1.2rem;"><span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem; color: #bfd6ff;">List / Set / Map</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem; color: #bfd6ff;">filter &amp; map</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem; color: #bfd6ff;">flatMap / reduce</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem; color: #bfd6ff;">Sequences</span></div>
// </div>
// <!-- Etapa 5 a 10 (mismo patrón) --> <!-- Etapa 5 -->
// <div style="position: relative; z-index: 2; background: rgba(12,20,35,0.85); backdrop-filter: blur(4px); border-radius: 2.5rem; margin-left: 2.8rem; margin-right: 0.5rem; padding: 1.8rem 2rem 1.8rem 3rem; border: 2px solid rgba(72,110,180,0.7);">
// <div style="position: absolute; left: -2.4rem; top: 1.2rem; width: 3.6rem; height: 3.6rem; background: linear-gradient(145deg, #1f2c48, #111a2c); border-radius: 50%; display: flex; align-items: center; justify-content: center; font-weight: bold; font-size: 2rem; border: 3px solid #5675c9; color: #cddcff;">5</div>
// <div><span style="font-size: 2.6rem; font-weight: bold; color: #ffffff;">POO en Kotlin</span></div>
// <div style="color: #cad2f0; font-size: 1.8rem;">Clases, herencia, modificadores, data classes, sealed classes, object.</div>
// <div style="display: flex; flex-wrap: wrap; gap: 1rem; margin-top: 1.2rem;"><span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem;">Constructor / propiedades</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem;">Herencia</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem;">Data classes</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem;">Sealed classes</span></div>
// </div>
// <!-- Etapa 6 -->
// <div style="position: relative; z-index: 2; background: rgba(12,20,35,0.85); backdrop-filter: blur(4px); border-radius: 2.5rem; margin-left: 2.8rem; margin-right: 0.5rem; padding: 1.8rem 2rem 1.8rem 3rem; border: 2px solid rgba(72,110,180,0.7);">
// <div style="position: absolute; left: -2.4rem; top: 1.2rem; width: 3.6rem; height: 3.6rem; background: linear-gradient(145deg, #1f2c48, #111a2c); border-radius: 50%; display: flex; align-items: center; justify-content: center; font-weight: bold; font-size: 2rem; border: 3px solid #5675c9; color: #cddcff;">6</div>
// <div><span style="font-size: 2.6rem; font-weight: bold; color: #ffffff;">Conceptos intermedios</span></div>
// <div style="color: #cad2f0; font-size: 1.8rem;">Extension functions, generics b&aacute;sicos, lateinit, lazy, destructuring.</div>
// <div style="display: flex; flex-wrap: wrap; gap: 1rem; margin-top: 1.2rem;"><span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem;">Extension functions</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem;">Generics (in/out)</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem;">lateinit / lazy</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem;">Destructuring</span></div>
// </div>
// <!-- Etapa 7 -->
// <div style="position: relative; z-index: 2; background: rgba(12,20,35,0.85); backdrop-filter: blur(4px); border-radius: 2.5rem; margin-left: 2.8rem; margin-right: 0.5rem; padding: 1.8rem 2rem 1.8rem 3rem; border: 2px solid rgba(72,110,180,0.7);">
// <div style="position: absolute; left: -2.4rem; top: 1.2rem; width: 3.6rem; height: 3.6rem; background: linear-gradient(145deg, #1f2c48, #111a2c); border-radius: 50%; display: flex; align-items: center; justify-content: center; font-weight: bold; font-size: 2rem; border: 3px solid #5675c9; color: #cddcff;">7</div>
// <div><span style="font-size: 2.6rem; font-weight: bold; color: #ffffff;">Manejo de errores</span></div>
// <div style="color: #cad2f0; font-size: 1.8rem;">try-catch-finally, runCatching, Result&lt;T&gt;.</div>
// <div style="display: flex; flex-wrap: wrap; gap: 1rem; margin-top: 1.2rem;"><span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem;">try-catch</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem;">runCatching</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem;">Result type</span></div>
// </div>
// <!-- Etapa 8 -->
// <div style="position: relative; z-index: 2; background: rgba(12,20,35,0.85); backdrop-filter: blur(4px); border-radius: 2.5rem; margin-left: 2.8rem; margin-right: 0.5rem; padding: 1.8rem 2rem 1.8rem 3rem; border: 2px solid rgba(72,110,180,0.7);">
// <div style="position: absolute; left: -2.4rem; top: 1.2rem; width: 3.6rem; height: 3.6rem; background: linear-gradient(145deg, #1f2c48, #111a2c); border-radius: 50%; display: flex; align-items: center; justify-content: center; font-weight: bold; font-size: 2rem; border: 3px solid #5675c9; color: #cddcff;">8</div>
// <div><span style="font-size: 2.6rem; font-weight: bold; color: #ffffff;">Corrutinas (asincron&iacute;a moderna)</span></div>
// <div style="color: #cad2f0; font-size: 1.8rem;">launch, async, suspend functions, Dispatchers, Flow, StateFlow.</div>
// <div style="display: flex; flex-wrap: wrap; gap: 1rem; margin-top: 1.2rem;"><span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem;">CoroutineScope</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem;">suspend functions</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem;">Flow API</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem;">StateFlow</span></div>
// </div>
// <!-- Etapa 9 -->
// <div style="position: relative; z-index: 2; background: rgba(12,20,35,0.85); backdrop-filter: blur(4px); border-radius: 2.5rem; margin-left: 2.8rem; margin-right: 0.5rem; padding: 1.8rem 2rem 1.8rem 3rem; border: 2px solid rgba(72,110,180,0.7);">
// <div style="position: absolute; left: -2.4rem; top: 1.2rem; width: 3.6rem; height: 3.6rem; background: linear-gradient(145deg, #1f2c48, #111a2c); border-radius: 50%; display: flex; align-items: center; justify-content: center; font-weight: bold; font-size: 2rem; border: 3px solid #5675c9; color: #cddcff;">9</div>
// <div><span style="font-size: 2.6rem; font-weight: bold; color: #ffffff;">Kotlin en el entorno real</span></div>
// <div style="color: #cad2f0; font-size: 1.8rem;">Backend (Spring + Ktor) &middot; Android + Compose &middot; KMP &middot; Kotlin/JS</div>
// <div style="margin-top: 1rem; background: #0f1829; border-radius: 1.5rem; padding: 0.8rem 1.4rem; font-size: 1.4rem; border-left: 5px solid #6290ff; color: #abb9e6;">🧩 Gradle, Exposed, Room, Retrofit, expect/actual multiplataforma</div>
// </div>
// <!-- Etapa 10 -->
// <div style="position: relative; z-index: 2; background: rgba(12,20,35,0.85); backdrop-filter: blur(4px); border-radius: 2.5rem; margin-left: 2.8rem; margin-right: 0.5rem; padding: 1.8rem 2rem 1.8rem 3rem; border: 2px solid rgba(72,110,180,0.7);">
// <div style="position: absolute; left: -2.4rem; top: 1.2rem; width: 3.6rem; height: 3.6rem; background: linear-gradient(145deg, #1f2c48, #111a2c); border-radius: 50%; display: flex; align-items: center; justify-content: center; font-weight: bold; font-size: 2rem; border: 3px solid #5675c9; color: #cddcff;">10</div>
// <div><span style="font-size: 2.6rem; font-weight: bold; color: #ffffff;">Proyectos pr&aacute;cticos &amp; portafolio</span></div>
// <div style="color: #cad2f0; font-size: 1.8rem;">Calculadora, app de tareas con Room, CLI, backend con Spring, app Android con Compose.</div>
// <div style="display: flex; flex-wrap: wrap; gap: 1rem; margin-top: 1.2rem;"><span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem;">Calculadora + historial</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem;">App Room + corrutinas</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem;">Backend Spring</span> <span style="background: rgba(45,70,115,0.6); border-radius: 60px; padding: 0.6rem 1.4rem; font-size: 1.3rem;">Android Compose</span></div>
// </div>
// </div>
// <hr style="margin: 2.5rem 0 1.2rem; border-color: #253458;">
// <div style="display: flex; flex-wrap: wrap; justify-content: space-between; align-items: center; gap: 1.2rem; font-size: 1.4rem;">
// <div>🧠 <strong>Roadmap lineal</strong> &mdash; sigue el orden recomendado. Cada bloque es prerrequisito del siguiente.</div>
// <div style="background: #101a30; border-radius: 40px; padding: 0.5rem 1.8rem; color: #bfd6ff; font-size: 1.4rem;">⚡ Practica con c&oacute;digo Kotlin en cada etapa</div>
// </div>
// </div>

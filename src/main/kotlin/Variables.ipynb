// %% [markdown]
// <div style="
//     background: linear-gradient(135deg, #1e1e2f 0%, #2a2a3b 100%);
//     border-radius: 16px;
//     padding: 20px;
//     margin: 20px 0;
//     box-shadow: 0 8px 20px rgba(0,0,0,0.3);
//     border-left: 5px solid #f37934;
//     font-family: 'Segoe UI', 'Roboto', system-ui, sans-serif;
// ">
//     <h2 style="
//         color: #f37934;
//         margin: 0;
//         font-size: 1.8rem;
//         font-weight: 700;
//         display: flex;
//         align-items: center;
//         gap: 12px;
//     ">
//         <span style="font-size: 2rem;">📦</span>
//         Variables y Constantes en Kotlin
//         <span style="
//             background: rgba(243, 121, 52, 0.2);
//             padding: 4px 12px;
//             border-radius: 20px;
//             font-size: 0.8rem;
//             font-weight: normal;
//             color: #ffb86c;
//             margin-left: 8px;
//         ">Kotlin Basics</span>
//     </h2>
// </div>

// %% [markdown]
// <div style="background: linear-gradient(135deg, #1e1e2f 0%, #2a2a3b 100%); border-radius: 16px; padding: 20px; margin: 20px 0; box-shadow: 0 8px 20px rgba(0,0,0,0.3); border-left: 5px solid #f37934; font-family: 'Segoe UI', 'Roboto', system-ui, sans-serif;">
// <h3 style="color: #f37934; margin: 0 0 16px 0; font-size: 1.6rem; font-weight: 600; border-bottom: 2px solid #f37934; display: inline-block; padding-bottom: 6px;">📦 Variables en Kotlin</h3>
// <details style="margin-top: 20px; background: rgba(30, 30, 47, 0.7); border-radius: 14px; padding: 12px 18px; transition: all 0.2s ease;">
// <summary style="font-weight: bold; font-size: 1.1rem; color: #f37934; cursor: pointer; user-select: none; list-style: none; display: flex; align-items: center; gap: 8px;"><span style="font-size: 1.3rem;">🔽</span> Ver explicaci&oacute;n</summary>
// <div style="margin-top: 20px; padding-left: 8px;">
// <h4 style="color: #ffb86c; margin: 0 0 10px 0; font-size: 1.2rem;">🤔 &iquest;Qu&eacute; es una variable?</h4>
// <p style="margin-left: 20px; margin-bottom: 20px; background: rgba(0,0,0,0.3); padding: 10px 14px; border-radius: 12px; border-left: 4px solid #f37934;"><em style="color: #d1d5d8;"> Una variable es un espacio de memoria que podemos reasignar m&uacute;ltiples veces. </em></p>
// <h4 style="color: #ffb86c; margin: 0 0 10px 0; font-size: 1.2rem;">🎯 &iquest;Para qu&eacute; sirven?</h4>
// <p style="margin-left: 20px; margin-bottom: 20px; background: rgba(0,0,0,0.3); padding: 10px 14px; border-radius: 12px; border-left: 4px solid #f37934;"><em style="color: #d1d5d8;"> Una variable sirve para guardar un dato temporalmente y efectuar acciones sobre &eacute;l. </em></p>
// <h4 style="color: #ffb86c; margin: 0 0 10px 0; font-size: 1.2rem;">🔢 &iquest;Cu&aacute;ntos tipos de variables existen?</h4>
// <p style="margin-left: 20px; background: rgba(0,0,0,0.3); padding: 10px 14px; border-radius: 12px; border-left: 4px solid #f37934;"><em style="color: #d1d5d8;"> En Kotlin existen 2 tipos de variables: las mutables </em> <code style="background: #2d2d44; color: #f37934; padding: 3px 8px; border-radius: 8px; font-weight: bold; font-family: monospace;">var</code> <em style="color: #d1d5d8;"> y las inmutables </em> <code style="background: #2d2d44; color: #f37934; padding: 3px 8px; border-radius: 8px; font-weight: bold; font-family: monospace;">val</code> <em style="color: #d1d5d8;">.</em></p>
// </div>
// </details>
// </div>

// %% [markdown]
// <div style="background: linear-gradient(135deg, #1e1e2f 0%, #2a2a3b 100%); border-radius: 16px; padding: 20px; margin: 20px 0; box-shadow: 0 8px 20px rgba(0,0,0,0.3); border-left: 5px solid #f37934; font-family: 'Segoe UI', 'Roboto', system-ui, sans-serif;">
// <h3 style="color: #f37934; margin: 0 0 16px 0; font-size: 1.6rem; font-weight: 600; border-bottom: 2px solid #f37934; display: inline-block; padding-bottom: 6px;">🔄 Variables mutables (<code style="background: #2d2d44; color: #f37934; padding: 3px 8px; border-radius: 8px; font-family: monospace;">var</code>)</h3>
// <details style="margin-top: 20px; background: rgba(30, 30, 47, 0.7); border-radius: 14px; padding: 12px 18px; transition: all 0.2s ease;">
// <summary style="font-weight: bold; font-size: 1.1rem; color: #f37934; cursor: pointer; user-select: none; list-style: none; display: flex; align-items: center; gap: 8px;"><span style="font-size: 1.3rem;">🔽</span> Ver explicaci&oacute;n</summary>
// <div style="margin-top: 20px; padding-left: 8px;">
// <p style="background: rgba(0,0,0,0.3); padding: 10px 14px; border-radius: 12px; border-left: 4px solid #f37934; margin-bottom: 24px; line-height: 1.5;"><span style="color: #d1d5d8;">En Kotlin, las </span> <strong style="color: #ffb86c;">variables mutables</strong> <span style="color: #d1d5d8;"> son aquellas cuyo valor puede cambiar despu&eacute;s de su asignaci&oacute;n inicial. Se definen utilizando la palabra reservada </span> <code style="background: #2d2d44; color: #f37934; padding: 3px 8px; border-radius: 8px; font-weight: bold; font-family: monospace;">var</code> <span style="color: #d1d5d8;">.</span></p>
// <h4 style="color: #ffb86c; margin: 20px 0 10px 0; font-size: 1.2rem;">⚙️ Caracter&iacute;sticas principales</h4>
// <ol style="background: rgba(0,0,0,0.3); padding: 10px 14px 10px 34px; border-radius: 12px; border-left: 4px solid #f37934; margin-bottom: 24px; color: #d1d5d8;">
// <li style="margin: 8px 0; line-height: 1.4;"><strong style="color: #ffb86c;">Reasignaci&oacute;n permitida</strong><span style="color: #d1d5d8;">: El valor puede cambiar m&uacute;ltiples veces</span></li>
// <li style="margin: 8px 0; line-height: 1.4;"><strong style="color: #ffb86c;">Tipo fijo</strong><span style="color: #d1d5d8;">: El tipo de dato no puede cambiar despu&eacute;s de la declaraci&oacute;n</span></li>
// <li style="margin: 8px 0; line-height: 1.4;"><strong style="color: #ffb86c;">Inicializaci&oacute;n flexible</strong><span style="color: #d1d5d8;">: Puede inicializarse despu&eacute;s de la declaraci&oacute;n (debe hacerse antes de usar)</span></li>
// </ol>
// <h4 style="color: #ffb86c; margin: 20px 0 10px 0; font-size: 1.2rem;">📍 &iquest;Cu&aacute;ndo usar <code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px; font-family: monospace;">var</code>?</h4>
// <ul style="background: rgba(0,0,0,0.3); padding: 10px 14px 10px 34px; border-radius: 12px; border-left: 4px solid #f37934; color: #d1d5d8;">
// <li style="margin: 8px 0; line-height: 1.4;">Cuando el valor necesita actualizarse (contadores, acumuladores)</li>
// <li style="margin: 8px 0; line-height: 1.4;">En propiedades que cambian de estado</li>
// <li style="margin: 8px 0; line-height: 1.4;">En bucles donde se modifica el iterador</li>
// </ul>
// </div>
// </details>
// </div>

// %% [markdown]
// <div style="background: linear-gradient(135deg, #1e1e2f 0%, #2a2a3b 100%); border-radius: 16px; padding: 20px; margin: 20px 0; box-shadow: 0 8px 20px rgba(0,0,0,0.3); border-left: 5px solid #f37934; font-family: 'Segoe UI', 'Roboto', system-ui, sans-serif;">
// <h3 style="color: #f37934; margin: 0 0 16px 0; font-size: 1.6rem; font-weight: 600; border-bottom: 2px solid #f37934; display: inline-block; padding-bottom: 6px;">🔒 Variables inmutables (<code style="background: #2d2d44; color: #f37934; padding: 3px 8px; border-radius: 8px; font-family: monospace;">val</code>)</h3>
//
// <details style="margin-top: 20px; background: rgba(30, 30, 47, 0.7); border-radius: 14px; padding: 12px 18px; transition: all 0.2s ease;">
// <summary style="font-weight: bold; font-size: 1.1rem; color: #f37934; cursor: pointer; user-select: none; list-style: none; display: flex; align-items: center; gap: 8px;"><span style="font-size: 1.3rem;">🔽</span> Ver explicaci&oacute;n</summary>
//
// <div style="background: rgba(30, 30, 47, 0.7); border-radius: 14px; padding: 12px 18px; transition: all 0.2s ease;">
// <div style="margin-top: 8px; padding-left: 8px;"><!-- Párrafo introductorio -->
// <p style="background: rgba(0,0,0,0.3); padding: 12px 16px; border-radius: 12px; border-left: 4px solid #f37934; margin-bottom: 24px; color: #d1d5d8; line-height: 1.5;"><span style="color: #d1d5d8;">En Kotlin, las </span> <strong style="color: #ffb86c;">variables inmutables</strong> <span style="color: #d1d5d8;"> son aquellas cuyo valor </span> <strong style="color: #ffb86c;">no puede cambiar</strong> <span style="color: #d1d5d8;"> despu&eacute;s de su asignaci&oacute;n inicial. Se definen utilizando la palabra clave </span> <code style="background: #2d2d44; color: #f37934; padding: 3px 8px; border-radius: 8px; font-weight: bold; font-family: monospace;">val</code> <span style="color: #d1d5d8;">.</span></p>
// <!-- Características principales -->
// <h4 style="color: #ffb86c; margin: 20px 0 10px 0; font-size: 1.2rem;">⚙️ Caracter&iacute;sticas principales</h4>
// <ol style="background: rgba(0,0,0,0.3); padding: 10px 14px 10px 34px; border-radius: 12px; border-left: 4px solid #f37934; margin-bottom: 24px; color: #d1d5d8;">
// <li style="margin: 8px 0; line-height: 1.4;"><strong style="color: #ffb86c;">Asignaci&oacute;n &uacute;nica</strong><span style="color: #d1d5d8;">: Solo se puede asignar un valor una vez</span></li>
// <li style="margin: 8px 0; line-height: 1.4;"><strong style="color: #ffb86c;">Inicializaci&oacute;n obligatoria</strong><span style="color: #d1d5d8;">: Debe inicializarse en el momento de la declaraci&oacute;n o en el constructor</span></li>
// <li style="margin: 8px 0; line-height: 1.4;"><strong style="color: #ffb86c;">Equivalente a "final" en Java</strong><span style="color: #d1d5d8;">: Similar a usar </span><code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px; font-family: monospace;">final</code><span style="color: #d1d5d8;"> en Java</span></li>
// </ol>
// <!-- Ventajas de usar val -->
// <h4 style="color: #ffb86c; margin: 20px 0 10px 0; font-size: 1.2rem;">✅ Ventajas de usar <code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px; font-family: monospace;">val</code></h4>
// <ol style="background: rgba(0,0,0,0.3); padding: 10px 14px 10px 34px; border-radius: 12px; border-left: 4px solid #f37934; margin-bottom: 24px; color: #d1d5d8;">
// <li style="margin: 8px 0; line-height: 1.4;"><strong style="color: #ffb86c;">Seguridad</strong><span style="color: #d1d5d8;">: Evita modificaciones accidentales</span></li>
// <li style="margin: 8px 0; line-height: 1.4;"><strong style="color: #ffb86c;">Legibilidad</strong><span style="color: #d1d5d8;">: Comunica la intenci&oacute;n de que el valor es constante</span></li>
// <li style="margin: 8px 0; line-height: 1.4;"><strong style="color: #ffb86c;">Inmutabilidad</strong><span style="color: #d1d5d8;">: Facilita el razonamiento sobre el c&oacute;digo y el multithreading</span></li>
// </ol>
// <!-- Mejores prácticas -->
// <h4 style="color: #ffb86c; margin: 20px 0 10px 0; font-size: 1.2rem;">💡 Mejores pr&aacute;cticas</h4>
// <ul style="background: rgba(0,0,0,0.3); padding: 10px 14px 10px 34px; border-radius: 12px; border-left: 4px solid #f37934; color: #d1d5d8;">
// <li style="margin: 8px 0; line-height: 1.4;"><strong style="color: #ffb86c;">Usar <code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">val</code> por defecto</strong><span style="color: #d1d5d8;"> siempre que sea posible</span></li>
// <li style="margin: 8px 0; line-height: 1.4;"><span style="color: #d1d5d8;">Cambiar a </span><code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">var</code><span style="color: #d1d5d8;"> solo cuando la variable </span><strong style="color: #ffb86c;">necesite</strong><span style="color: #d1d5d8;"> mutar</span></li>
// <li style="margin: 8px 0; line-height: 1.4;"><span style="color: #d1d5d8;">Las variables inmutables hacen el c&oacute;digo m&aacute;s predecible y f&aacute;cil de depurar</span></li>
// </ul>
// </div>
// </div>
// </details>

// %% [markdown]
// <div style="background: linear-gradient(135deg, #1e1e2f 0%, #2a2a3b 100%); border-radius: 16px; padding: 20px; margin: 20px 0; box-shadow: 0 8px 20px rgba(0,0,0,0.3); border-left: 5px solid #f37934; font-family: 'Segoe UI', 'Roboto', system-ui, sans-serif;">
// <h3 style="color: #f37934; margin: 0 0 16px 0; font-size: 1.6rem; font-weight: 600; border-bottom: 2px solid #f37934; display: inline-block; padding-bottom: 6px;">📊 Tipos B&aacute;sicos de Datos en Kotlin</h3>
// <details style="margin-top: 20px; background: rgba(30, 30, 47, 0.7); border-radius: 14px; padding: 12px 18px; transition: all 0.2s ease;">
// <summary style="font-weight: bold; font-size: 1.1rem; color: #f37934; cursor: pointer; user-select: none; list-style: none; display: flex; align-items: center; gap: 8px;"><span style="font-size: 1.3rem;">🔽</span> Ver explicaci&oacute;n</summary>
// <div style="margin-top: 20px;"><!-- Intro box -->
// <div style="background: rgba(0,0,0,0.3); padding: 12px 16px; border-radius: 12px; border-left: 4px solid #f37934; margin-bottom: 24px; color: #d1d5d8; line-height: 1.5;">Kotlin es un lenguaje de tipado est&aacute;tico. Todos los tipos mostrados son objetos (no tipos primitivos tradicionales).<br>Los valores m&iacute;nimos y m&aacute;ximos corresponden a los rangos de cada tipo num&eacute;rico.</div>
// <!-- Tabla estilizada -->
// <div style="overflow-x: auto;">
// <table style="width: 100%; border-collapse: collapse; background: rgba(0,0,0,0.3); border-radius: 12px; overflow: hidden; margin-bottom: 24px; color: #d1d5d8;">
// <thead>
// <tr style="background: rgba(243, 121, 52, 0.2); border-bottom: 2px solid #f37934;">
// <th style="padding: 12px; text-align: left; font-weight: 600; color: #ffb86c;">Tipo</th>
// <th style="padding: 12px; text-align: left; font-weight: 600; color: #ffb86c;">Descripci&oacute;n</th>
// <th style="padding: 12px; text-align: left; font-weight: 600; color: #ffb86c;">Tama&ntilde;o (bits)</th>
// <th style="padding: 12px; text-align: left; font-weight: 600; color: #ffb86c;">Valor M&iacute;nimo</th>
// <th style="padding: 12px; text-align: left; font-weight: 600; color: #ffb86c;">Valor M&aacute;ximo</th>
// <th style="padding: 12px; text-align: left; font-weight: 600; color: #ffb86c;">Ejemplo</th>
// </tr>
// </thead>
// <tbody>
// <tr style="border-bottom: 1px solid rgba(243, 121, 52, 0.3);">
// <td style="padding: 10px; font-weight: bold; color: #f37934;">Byte</td>
// <td style="padding: 10px;">N&uacute;mero entero de 8 bits con signo</td>
// <td style="padding: 10px;">8</td>
// <td style="padding: 10px;">-128</td>
// <td style="padding: 10px;">127</td>
// <td style="padding: 10px;"><code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">val edad: Byte = 25</code></td>
// </tr>
// <tr style="border-bottom: 1px solid rgba(243, 121, 52, 0.3);">
// <td style="padding: 10px; font-weight: bold; color: #f37934;">Short</td>
// <td style="padding: 10px;">N&uacute;mero entero de 16 bits con signo</td>
// <td style="padding: 10px;">16</td>
// <td style="padding: 10px;">-32,768</td>
// <td style="padding: 10px;">32,767</td>
// <td style="padding: 10px;"><code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">val temperatura: Short = 32000</code></td>
// </tr>
// <tr style="border-bottom: 1px solid rgba(243, 121, 52, 0.3);">
// <td style="padding: 10px; font-weight: bold; color: #f37934;">Int</td>
// <td style="padding: 10px;">N&uacute;mero entero de 32 bits con signo (m&aacute;s com&uacute;n)</td>
// <td style="padding: 10px;">32</td>
// <td style="padding: 10px;">-2,147,483,648</td>
// <td style="padding: 10px;">2,147,483,647</td>
// <td style="padding: 10px;"><code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">val poblacion: Int = 8_000_000</code></td>
// </tr>
// <tr style="border-bottom: 1px solid rgba(243, 121, 52, 0.3);">
// <td style="padding: 10px; font-weight: bold; color: #f37934;">Long</td>
// <td style="padding: 10px;">N&uacute;mero entero de 64 bits con signo</td>
// <td style="padding: 10px;">64</td>
// <td style="padding: 10px;">-9,223,372,036,854,775,808</td>
// <td style="padding: 10px;">9,223,372,036,854,775,807</td>
// <td style="padding: 10px;"><code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">val distancia: Long = 100_000L</code></td>
// </tr>
// <tr style="border-bottom: 1px solid rgba(243, 121, 52, 0.3);">
// <td style="padding: 10px; font-weight: bold; color: #f37934;">Float</td>
// <td style="padding: 10px;">N&uacute;mero de punto flotante (precisi&oacute;n simple)</td>
// <td style="padding: 10px;">32</td>
// <td style="padding: 10px;">-3.4028235e38</td>
// <td style="padding: 10px;">3.4028235e38</td>
// <td style="padding: 10px;"><code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">val precio: Float = 19.99f</code></td>
// </tr>
// <tr style="border-bottom: 1px solid rgba(243, 121, 52, 0.3);">
// <td style="padding: 10px; font-weight: bold; color: #f37934;">Double</td>
// <td style="padding: 10px;">N&uacute;mero de punto flotante (precisi&oacute;n doble)</td>
// <td style="padding: 10px;">64</td>
// <td style="padding: 10px;">-1.7976931348623157e308</td>
// <td style="padding: 10px;">1.7976931348623157e308</td>
// <td style="padding: 10px;"><code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">val pi: Double = 3.1415926535</code></td>
// </tr>
// <tr style="border-bottom: 1px solid rgba(243, 121, 52, 0.3);">
// <td style="padding: 10px; font-weight: bold; color: #f37934;">Boolean</td>
// <td style="padding: 10px;">Valor l&oacute;gico verdadero/falso</td>
// <td style="padding: 10px;">1 (l&oacute;gicamente)</td>
// <td style="padding: 10px;">false</td>
// <td style="padding: 10px;">true</td>
// <td style="padding: 10px;"><code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">val activado: Boolean = true</code></td>
// </tr>
// <tr style="border-bottom: 1px solid rgba(243, 121, 52, 0.3);">
// <td style="padding: 10px; font-weight: bold; color: #f37934;">Char</td>
// <td style="padding: 10px;">Un solo car&aacute;cter Unicode</td>
// <td style="padding: 10px;">16</td>
// <td style="padding: 10px;">'\u0000' (0)</td>
// <td style="padding: 10px;">'\uFFFF' (65535)</td>
// <td style="padding: 10px;"><code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">val letra: Char = 'A'</code></td>
// </tr>
// <tr>
// <td style="padding: 10px; font-weight: bold; color: #f37934;">String</td>
// <td style="padding: 10px;">Cadena de caracteres (inmutable)</td>
// <td style="padding: 10px;">Variable</td>
// <td style="padding: 10px;">-</td>
// <td style="padding: 10px;">-</td>
// <td style="padding: 10px;"><code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">val nombre: String = "Kotlin"</code></td>
// </tr>
// </tbody>
// </table>
// </div>
// <!-- Notas importantes -->
// <details style="margin-top: 20px;">
// <summary style="cursor: pointer; background: rgba(243, 121, 52, 0.2); color: #f37934; padding: 10px; border-radius: 10px; font-weight: bold; display: inline-block; width: auto; border: 1px solid #f37934;">📝 Notas importantes sobre los tipos en Kotlin</summary>
// <div style="background: rgba(0,0,0,0.3); padding: 16px; border-radius: 12px; border-left: 4px solid #f37934; margin-top: 12px; color: #d1d5d8; line-height: 1.6;"><strong style="color: #ffb86c;">✨ Inferencia de tipos:</strong> Kotlin puede deducir autom&aacute;ticamente el tipo, por lo que no siempre es necesario declararlo:<br><code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">val mensaje = "Hola"</code> &rarr; se infiere como String autom&aacute;ticamente.<br><br><strong style="color: #ffb86c;">🔢 Sufijos para n&uacute;meros:</strong><br>&bull; <code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">L</code> para Long: <code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">100_000L</code><br>&bull; <code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">f</code> o <code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">F</code> para Float: <code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">19.99f</code><br>&bull; <code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">_</code> para separar d&iacute;gitos: <code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">1_000_000</code><br><br><strong style="color: #ffb86c;">⚠️ Tipos nullable:</strong> Por defecto, ninguna variable puede ser null a menos que se declare expl&iacute;citamente con <code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">?</code>:<br><code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">var texto: String? = null</code> &rarr; puede contener null.<br><br><strong style="color: #ffb86c;">📏 Rangos:</strong> Los valores m&iacute;nimos y m&aacute;ximos est&aacute;n disponibles mediante constantes:<br><code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">Byte.MIN_VALUE</code>, <code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">Int.MAX_VALUE</code>, etc.</div>
// </details>
// </div>
// </details>
// </div>

// %% [markdown]
// <div style="background: linear-gradient(135deg, #1e1e2f 0%, #2a2a3b 100%); border-radius: 16px; padding: 20px; margin: 20px 0; box-shadow: 0 8px 20px rgba(0,0,0,0.3); border-left: 5px solid #f37934; font-family: 'Segoe UI', 'Roboto', system-ui, sans-serif;">
// <h3 style="color: #f37934; margin: 0 0 16px 0; font-size: 1.6rem; font-weight: 600; border-bottom: 2px solid #f37934; display: inline-block; padding-bottom: 6px;">⚡ Constantes en Kotlin (<code style="background: #2d2d44; color: #f37934; padding: 3px 8px; border-radius: 8px; font-family: monospace;">const val</code>)</h3>
// <details style="margin-top: 20px; background: rgba(30, 30, 47, 0.7); border-radius: 14px; padding: 12px 18px; transition: all 0.2s ease;">
// <summary style="font-weight: bold; font-size: 1.1rem; color: #f37934; cursor: pointer; user-select: none; list-style: none; display: flex; align-items: center; gap: 8px;"><span style="font-size: 1.3rem;">🔽</span> Ver explicaci&oacute;n</summary>
// <div style="margin-top: 20px; padding-left: 8px;"><!-- Párrafo introductorio -->
// <p style="background: rgba(0,0,0,0.3); padding: 12px 16px; border-radius: 12px; border-left: 4px solid #f37934; margin-bottom: 24px; color: #d1d5d8; line-height: 1.5;"><span style="color: #d1d5d8;">En Kotlin, una </span> <strong style="color: #ffb86c;">constante</strong> <span style="color: #d1d5d8;"> es un valor inmutable que se conoce en </span> <strong style="color: #ffb86c;">tiempo de compilaci&oacute;n</strong> <span style="color: #d1d5d8;">. Se define usando </span> <code style="background: #2d2d44; color: #f37934; padding: 3px 8px; border-radius: 8px; font-weight: bold; font-family: monospace;">const val</code> <span style="color: #d1d5d8;"> y debe cumplir requisitos espec&iacute;ficos.</span></p>
// <!-- Requisitos importantes -->
// <h4 style="color: #ffb86c; margin: 20px 0 10px 0; font-size: 1.2rem;">📋 Requisitos importantes</h4>
// <p style="background: rgba(0,0,0,0.3); padding: 10px 14px; border-radius: 12px; border-left: 4px solid #f37934; margin-bottom: 16px; color: #d1d5d8;">Las constantes en Kotlin deben cumplir:</p>
// <ol style="background: rgba(0,0,0,0.3); padding: 10px 14px 10px 34px; border-radius: 12px; border-left: 4px solid #f37934; margin-bottom: 24px; color: #d1d5d8;">
// <li style="margin: 8px 0; line-height: 1.4;"><strong style="color: #ffb86c;">Tipo primitivo o String</strong><span style="color: #d1d5d8;">: Solo </span><code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">String</code><span style="color: #d1d5d8;"> o tipos primitivos (</span><code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">Int</code><span style="color: #d1d5d8;">, </span><code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">Double</code><span style="color: #d1d5d8;">, </span><code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">Boolean</code><span style="color: #d1d5d8;">, etc.)</span></li>
// <li style="margin: 8px 0; line-height: 1.4;"><strong style="color: #ffb86c;">Top-level o dentro de un </strong><code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;"><strong style="color: #ffb86c;">object</strong></code><span style="color: #d1d5d8;">: No pueden estar dentro de una clase regular</span></li>
// <li style="margin: 8px 0; line-height: 1.4;"><strong style="color: #ffb86c;">Inicializaci&oacute;n en tiempo de compilaci&oacute;n</strong><span style="color: #d1d5d8;">: El valor debe conocerse al compilar</span></li>
// </ol>
// <!-- Cuándo usar const val -->
// <h4 style="color: #ffb86c; margin: 20px 0 10px 0; font-size: 1.2rem;">🎯 &iquest;Cu&aacute;ndo usar <code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">const val</code>?</h4>
// <ul style="background: rgba(0,0,0,0.3); padding: 10px 14px 10px 34px; border-radius: 12px; border-left: 4px solid #f37934; margin-bottom: 24px; color: #d1d5d8;">
// <li style="margin: 8px 0; line-height: 1.4;"><strong style="color: #ffb86c;">Valores verdaderamente constantes</strong><span style="color: #d1d5d8;"> como configuraciones, URLs, keys de API</span></li>
// <li style="margin: 8px 0; line-height: 1.4;"><strong style="color: #ffb86c;">Mejora el rendimiento</strong><span style="color: #d1d5d8;"> porque los valores se inlinen en tiempo de compilaci&oacute;n</span></li>
// <li style="margin: 8px 0; line-height: 1.4;"><strong style="color: #ffb86c;">En anotaciones</strong><span style="color: #d1d5d8;"> donde se requieren constantes en tiempo de compilaci&oacute;n</span></li>
// </ul>
// <!-- Tabla comparativa -->
// <h4 style="color: #ffb86c; margin: 20px 0 10px 0; font-size: 1.2rem;">📊 Comparaci&oacute;n: <code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">const val</code> vs <code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">val</code></h4>
// <div style="overflow-x: auto; margin-bottom: 24px;">
// <table style="width: 100%; border-collapse: collapse; background: rgba(0,0,0,0.3); border-radius: 12px; overflow: hidden; color: #d1d5d8;">
// <thead>
// <tr style="background: rgba(243, 121, 52, 0.2); border-bottom: 2px solid #f37934;">
// <th style="padding: 12px; text-align: left; font-weight: 600; color: #ffb86c;">Caracter&iacute;stica</th>
// <th style="padding: 12px; text-align: left; font-weight: 600; color: #ffb86c;"><code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">const val</code></th>
// <th style="padding: 12px; text-align: left; font-weight: 600; color: #ffb86c;"><code style="background: #2d2d44; color: #f37934; padding: 2px 6px; border-radius: 6px;">val</code></th>
// </tr>
// </thead>
// <tbody>
// <tr style="border-bottom: 1px solid rgba(243, 121, 52, 0.3);">
// <td style="padding: 10px;">Tiempo de evaluaci&oacute;n</td>
// <td style="padding: 10px;">Compilaci&oacute;n</td>
// <td style="padding: 10px;">Ejecuci&oacute;n</td>
// </tr>
// <tr style="border-bottom: 1px solid rgba(243, 121, 52, 0.3);">
// <td style="padding: 10px;">Tipos permitidos</td>
// <td style="padding: 10px;">Primitivos + String</td>
// <td style="padding: 10px;">Cualquier tipo</td>
// </tr>
// <tr style="border-bottom: 1px solid rgba(243, 121, 52, 0.3);">
// <td style="padding: 10px;">Ubicaci&oacute;n</td>
// <td style="padding: 10px;">Top-level u object</td>
// <td style="padding: 10px;">Cualquier lugar</td>
// </tr>
// <tr>
// <td style="padding: 10px;">Rendimiento</td>
// <td style="padding: 10px;">Mejor (inline)</td>
// <td style="padding: 10px;">Normal</td>
// </tr>
// </tbody>
// </table>
// </div>
// </div>
// </details>
